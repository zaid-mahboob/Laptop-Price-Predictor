# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("laptop_data.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
dataset.shape
# Out:
# (1303, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# In the first step we are going to remove unnammed column from our dataset.

# %%
dataset.drop(columns=["Unnamed: 0"])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %% [markdown]
# Now we are going to remove GB from RAM column to get only numbers in the RAM Column

# %%
dataset['Ram'] = dataset['Ram'].str.replace('GB', '')
dataset['Ram'] = dataset['Ram'].astype('int32')

# %% [markdown]
# Now we are going to remove kg from weight column to get only numbers in the weight Column

# %%
dataset['Weight'] = dataset['Weight'].str.replace('kg', '')
dataset['Weight'] = dataset['Weight'].astype('float32')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), object(7)
# memory usage: 112.1+ KB

# %% [markdown]
# Now we are going to do a bit of analysis of data using Seaborn Library

# %%
import seaborn as sns

# %%
sns.distplot(dataset['Price'])
# Out:
# C:\Users\Zaid\AppData\Local\Temp\ipykernel_11012\983781003.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Price'])
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
dataset['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=dataset['Company'], y=dataset['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
dataset['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=dataset['TypeName'], y=dataset['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.distplot(dataset['Inches'])
# Out:
# C:\Users\Zaid\AppData\Local\Temp\ipykernel_11012\850755342.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Inches'])
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
dataset['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# Now as we can see that over here in this one column we have multiple information such as touchscreen, IPS panel, Resolution, etc. So we will split all this into different columns

# %%
dataset['Touch Screen'] = dataset['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
dataset.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# ...

# %%
dataset['Touch Screen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = dataset['Touch Screen'], y = dataset['Price'])
# Out:
# <AxesSubplot:xlabel='Touch Screen', ylabel='Price'>

# %%
dataset['IPS'] = dataset['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
dataset['Touch Screen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
new  = dataset['ScreenResolution'].str.split('x', n=1, expand = True)

# %%
dataset['X_res'] = new[0]
dataset['Y_res'] = new[1]

# %%
dataset.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# ...

# %%
dataset['X_res'] = dataset['X_res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
dataset.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# ...

# %%
dataset['X_res'] = dataset['X_res'].astype('int')
dataset['Y_res'] = dataset['Y_res'].astype('int')

# %%
dataset = dataset.drop(columns=['Unnamed: 0'])

# %%
dataset.corr()['Price']
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price           1.000000
# Touch Screen    0.191226
# IPS             0.252208
# X_res           0.556529
# Y_res           0.552809
# Name: Price, dtype: float64

# %%
dataset['ppi'] = ((dataset['X_res']**2 + dataset['Y_res']**2)**0.5 / dataset['Inches']).astype('float')

# %%
dataset.drop(columns = ['ScreenResolution'])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...

# %%
dataset.drop(columns = ['X_res', 'Y_res', 'Inches'])
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
dataset.drop(columns=["ScreenResolution"])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...

# %%
dataset.drop(columns= ["Inches", "X_res", "Y_res"])
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
dataset = dataset.drop(columns= ["ScreenResolution", "Inches", "X_res", "Y_res"])

# %%
dataset.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS         ppi
# 0    1  226.983005
# 1    0  127.677940
# ...

# %%
dataset["Cpu"].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
dataset["Cpu Name"] = dataset["Cpu"].apply(lambda x: x.split()[0:3])

# %%
dataset.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS         ppi           Cpu Name
# ...

# %%
def fetchprocessor(text):
    text = " ".join(text)
    if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
        return text
    else: 
        if text.split()[0] == "Intel":
            return "Other Intel Processor"
        else :
            return "AMD Processor"

# %%
dataset["CPU Brand"] = dataset["Cpu Name"].apply(fetchprocessor)

# %%
dataset.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touch Screen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS         ppi           Cpu Name      CPU Brand
# ...

# %%
dataset = dataset.drop(columns= ["Cpu", "Cpu Name"])

# %%
dataset["CPU Brand"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = dataset["CPU Brand"], y = dataset["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
dataset["Ram"].value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
sns.barplot(x = dataset["Ram"], y = dataset["Price"])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
dataset["Memory"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df = dataset

# %%
df["Memory"] = df["Memory"].astype(str).replace("\.0" , "",regex = True)
df["Memory"]
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name: Memory, Length: 1303, dtype: object

# %%
df["Memory"] = df["Memory"].str.replace('GB', "")
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
df["first"] = new[0]
df["first"] = df["first"].str.strip()

# %%
df["second"] = new[1]

# %%
df["first"]
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1298              128 SSD
# 1299              512 SSD
# 1300     64 Flash Storage
# 1301             1000 HDD
# 1302              500 HDD
# Name: first, Length: 1303, dtype: object

# %%
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df["first"] = df["first"].str.replace(r'\D', "")  # this removes all the words from the string and only leaves the int part

#df["second"] = df["second"].fillna("0", inplace=True)
# Out:
# C:\Users\Zaid\AppData\Local\Temp\ipykernel_11012\2840207539.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["first"] = df["first"].str.replace(r'\D', "")  # this removes all the words from the string and only leaves the int part

# %%
df["first"]
# Out:
# 0        128
# 1        128
# 2        256
# 3        512
# 4        256
#         ...
# 1298     128
# 1299     512
# 1300      64
# 1301    1000
# 1302     500
# Name: first, Length: 1303, dtype: object

# %%
df["second"] = df["second"].fillna("0")
df["second"].unique()
# Out:
# array(['0', '  1000 HDD', '  256 SSD', '  2000 HDD', '  500 HDD',
#        '  512 SSD', '  1000 Hybrid'], dtype=object)

# %%
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df["second"] = df["second"].str.replace(r'\D', "")

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)
# Out:
# C:\Users\Zaid\AppData\Local\Temp\ipykernel_11012\3408928854.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["second"] = df["second"].str.replace(r'\D', "")

# %%
df["Layer2HDD"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["first"]
# Out:
# 0        128
# 1        128
# 2        256
# 3        512
# 4        256
#         ...
# 1298     128
# 1299     512
# 1300      64
# 1301    1000
# 1302     500
# Name: first, Length: 1303, dtype: int32

# %%
df["HDD"] = (df["first"]*df["Layer1HDD"] + df["second"]*df["Layer2HDD"])
df["SSD"] = (df["first"]*df["Layer1SSD"] + df["second"]*df["Layer2SSD"])
df["Hybrid"] = (df["first"]*df["Layer1Hybrid"] + df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"]*df["Layer1Flash_Storage"] + df["second"]*df["Layer2Flash_Storage"])

# %%
df["HDD"].unique()
# Out:
# array([   0,  500, 1000, 2000,   32,  128], dtype=int64)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touch Screen  IPS  ...  Layer1Hybrid  \
# 0  macOS    1.37   71378.6832             0    1  ...             0
# 1  macOS    1.34   47895.5232             0    0  ...             0
# 2  No OS    1.86   30636.0000             0    0  ...             0
# 3  macOS    1.83  135195.3360             0    1  ...             0
# 4  macOS    1.37   96095.8080             0    1  ...             0
#
#   Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df = df.drop(columns= ['first', 'second' , 'Layer1HDD', "Layer1SSD", 'Layer1Hybrid', 'Layer1Flash_Storage', 'Layer2HDD', "Layer2SSD", 'Layer2Hybrid', 'Layer2Flash_Storage'])

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram            Memory  \
# 773     Dell              Gaming    8          1000 HDD
# 828     Acer             Netbook    4  32 Flash Storage
# 959     Acer  2 in 1 Convertible    4  32 Flash Storage
# 857       HP  2 in 1 Convertible    8           256 SSD
# 963  Toshiba           Ultrabook    8           512 SSD
#
#                          Gpu       OpSys  Weight      Price  Touch Screen  \
# 773  Nvidia GeForce GTX 1050  Windows 10    2.62   58554.72             0
# 828    Intel HD Graphics 400   Chrome OS    1.35   18914.40             0
# 959    Intel HD Graphics 400   Chrome OS    1.25   20725.92             1
# 857    Intel HD Graphics 620  Windows 10    1.28  136343.52             1
# 963    Intel HD Graphics 620  Windows 10    1.10   95371.20             1
#
#      IPS         ppi              CPU Brand   HDD  SSD  Hybrid  Flash_Storage
# 773    0  141.211998          Intel Core i7  1000    0       0              0
# ...

# %%
df = df.drop(columns = "Memory")

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touch Screen  IPS         ppi      CPU Brand  HDD  SSD  \
# 0   71378.6832             0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232             0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000             0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360             0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080             0    1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0
# ...

# %%
df.corr()["Price"]
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touch Screen     0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df = df.drop(columns = ["Hybrid", "Flash_Storage"])

# %%
df["Gpu"].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df["Gpu Brand"] = df["Gpu"].apply(lambda x : x.split()[0]) # the purpose of lambda function is that it apply this to each element one by one.

# %%
df["Gpu Brand"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touch Screen  IPS         ppi      CPU Brand  HDD  SSD  \
# 0   71378.6832             0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232             0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000             0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360             0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080             0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df.corr()["Price"]
# Out:
# Ram             0.743007
# Weight          0.210370
# Price           1.000000
# Touch Screen    0.191226
# IPS             0.252208
# ppi             0.473487
# HDD            -0.096441
# SSD             0.670799
# Name: Price, dtype: float64

# %%
df = df[df["Gpu Brand"] != "ARM"]

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touch Screen  IPS         ppi      CPU Brand  HDD  SSD  \
# 0   71378.6832             0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232             0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000             0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360             0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080             0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
sns.barplot(x = df["Gpu Brand"], y = df["Price"])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df = df.drop(columns = "Gpu")

# %%
df["OpSys"].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x = df["OpSys"], y = df["Price"])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touch Screen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832             0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232             0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000             0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360             0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080             0    1
#
#           ppi      CPU Brand  HDD  SSD Gpu Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
def oos(text):
    if text == "Windows 10" or text == "Windows 7" or text == "Windows 10 S":
        return "Windows"
    elif text == "macOS" or text == "Mac OS X":
        return "Mac"
    else :
        return "Other"

# %%
df["os"] = df["OpSys"].apply(oos)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touch Screen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832             0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232             0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000             0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360             0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080             0    1
#
#           ppi      CPU Brand  HDD  SSD Gpu Brand     os
# 0  226.983005  Intel Core i5    0  128     Intel    Mac
# 1  127.677940  Intel Core i5    0    0     Intel    Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Other
# 3  220.534624  Intel Core i7    0  512       AMD    Mac
# 4  226.983005  Intel Core i5    0  256     Intel    Mac

# %%
df["os"].unique()
# Out:
# array(['Mac', 'Other', 'Windows'], dtype=object)

# %%
df = df.drop(columns = "OpSys")

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
x = df.drop(columns = "Price")

# %%
y = df["Price"]

# %%
y = np.log(y)

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.15, random_state= 2 )

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_absolute_error

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(sparse = False, drop = 'first'), [0,1,7,10,11])
], remainder='passthrough')
step2 = LinearRegression()

pipe  = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)

print ("R2 Score", r2_score(y_test, y_pred))
print ("MAE", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score 0.8073277448418622
# MAE 0.21017827976428838

# %%
from sklearn.ensemble import RandomForestRegressor
step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(sparse = False, drop = 'first'), [0,1,7,10,11])
], remainder='passthrough')
step2 = RandomForestRegressor(n_estimators=300, random_state = 3, max_samples = 0.5, max_features= 0.1, max_depth = 20)

pipe  = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)

print ("R2 Score", r2_score(y_test, y_pred))
print ("MAE", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score 0.9017845063495822
# MAE 0.1479789694098753
